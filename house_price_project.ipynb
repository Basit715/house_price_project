# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import stats as st
import scipy


import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder,OrdinalEncoder

from sklearn.linear_model import LinearRegression,Ridge,ElasticNet,Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.kernel_ridge import KernelRidge

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
train_df.describe().T
# Out:
#                 count           mean  ...        75%       max
# Id             1460.0     730.500000  ...    1095.25    1460.0
# MSSubClass     1460.0      56.897260  ...      70.00     190.0
# LotFrontage    1201.0      70.049958  ...      80.00     313.0
# LotArea        1460.0   10516.828082  ...   11601.50  215245.0
# OverallQual    1460.0       6.099315  ...       7.00      10.0
# OverallCond    1460.0       5.575342  ...       6.00       9.0
# YearBuilt      1460.0    1971.267808  ...    2000.00    2010.0
# YearRemodAdd   1460.0    1984.865753  ...    2004.00    2010.0
# MasVnrArea     1452.0     103.685262  ...     166.00    1600.0
# BsmtFinSF1     1460.0     443.639726  ...     712.25    5644.0
# BsmtFinSF2     1460.0      46.549315  ...       0.00    1474.0
# BsmtUnfSF      1460.0     567.240411  ...     808.00    2336.0
# TotalBsmtSF    1460.0    1057.429452  ...    1298.25    6110.0
# 1stFlrSF       1460.0    1162.626712  ...    1391.25    4692.0
# 2ndFlrSF       1460.0     346.992466  ...     728.00    2065.0
# LowQualFinSF   1460.0       5.844521  ...       0.00     572.0
# GrLivArea      1460.0    1515.463699  ...    1776.75    5642.0
# BsmtFullBath   1460.0       0.425342  ...       1.00       3.0
# BsmtHalfBath   1460.0       0.057534  ...       0.00       2.0
# FullBath       1460.0       1.565068  ...       2.00       3.0
# HalfBath       1460.0       0.382877  ...       1.00       2.0
# BedroomAbvGr   1460.0       2.866438  ...       3.00       8.0
# KitchenAbvGr   1460.0       1.046575  ...       1.00       3.0
# TotRmsAbvGrd   1460.0       6.517808  ...       7.00      14.0
# Fireplaces     1460.0       0.613014  ...       1.00       3.0
# GarageYrBlt    1379.0    1978.506164  ...    2002.00    2010.0
# GarageCars     1460.0       1.767123  ...       2.00       4.0
# GarageArea     1460.0     472.980137  ...     576.00    1418.0
# WoodDeckSF     1460.0      94.244521  ...     168.00     857.0
# OpenPorchSF    1460.0      46.660274  ...      68.00     547.0
# EnclosedPorch  1460.0      21.954110  ...       0.00     552.0
# 3SsnPorch      1460.0       3.409589  ...       0.00     508.0
# ScreenPorch    1460.0      15.060959  ...       0.00     480.0
# PoolArea       1460.0       2.758904  ...       0.00     738.0
# MiscVal        1460.0      43.489041  ...       0.00   15500.0
# MoSold         1460.0       6.321918  ...       8.00      12.0
# YrSold         1460.0    2007.815753  ...    2009.00    2010.0
# SalePrice      1460.0  180921.195890  ...  214000.00  755000.0
#
# [38 rows x 8 columns]

# %%
train_df.dtypes[train_df.dtypes!='object']
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
plt.scatter(x='MSSubClass', y='SalePrice', data=train_df)

# %%
plt.scatter(x='LotFrontage', y='SalePrice', data=train_df)

# %%
train_df.query('LotFrontage > 300')
# Drop 935 and 1299
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 934    935          20       RL  ...        WD         Normal    242000
# 1298  1299          60       RL  ...       New        Partial    160000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='LotArea', y='SalePrice', data=train_df)

# %%
train_df.query('LotArea > 55000')
# Drop 250, 314, 336, 707
#may be 1397
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 249    250          50       RL  ...        WD         Normal    277000
# 313    314          20       RL  ...        WD         Normal    375000
# 335    336         190       RL  ...        WD         Normal    228950
# 451    452          20       RL  ...        WD         Normal    280000
# 706    707          20       RL  ...        WD         Normal    302000
# 1298  1299          60       RL  ...       New        Partial    160000
# 1396  1397          20       RL  ...        WD         Normal    160000
#
# [7 rows x 81 columns]

# %%
plt.scatter(x='OverallQual', y='SalePrice', data=train_df)

# %%
train_df.query('OverallQual == 10')
# Drop 524,
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 58      59          60       RL  ...       New        Partial    438780
# 185    186          75       RM  ...        WD         Normal    475000
# 224    225          20       RL  ...        WD         Normal    386250
# 389    390          60       RL  ...       New        Partial    426000
# 440    441          20       RL  ...        WD         Normal    555000
# 515    516          20       RL  ...       New        Partial    402861
# 523    524          60       RL  ...       New        Partial    184750
# 583    584          75       RM  ...        WD         Normal    325000
# 591    592          60       RL  ...     ConLI         Normal    451950
# 691    692          60       RL  ...        WD         Normal    755000
# 825    826          20       RL  ...       New        Partial    385000
# 994    995          20       RL  ...        WD         Normal    337500
# 1169  1170          60       RL  ...        WD         Normal    625000
# 1182  1183          60       RL  ...        WD        Abnorml    745000
# 1243  1244          20       RL  ...       New        Partial    465000
# 1298  1299          60       RL  ...       New        Partial    160000
# 1373  1374          20       RL  ...        WD         Normal    466500
# 1442  1443          60       FV  ...        WD         Normal    310000
#
# [18 rows x 81 columns]

# %%
plt.scatter(x='OverallCond', y='SalePrice', data=train_df)

# %%
train_df.query('OverallCond == 2')
# Drop 379
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 88    89          50  C (all)  ...     ConLD        Abnorml     85000
# 250  251          30       RL  ...        WD         Normal     76500
# 378  379          20       RL  ...       New        Partial    394432
# 398  399          30       RM  ...        WD        Abnorml     67000
# 676  677          70       RM  ...        WD         Normal     87000
#
# [5 rows x 81 columns]

# %%
train_df.query('OverallCond == 5 & SalePrice > 700000')
# Drop 1183
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1182  1183          60       RL  ...        WD        Abnorml    745000
#
# [1 rows x 81 columns]

# %%
train_df.query('OverallCond == 6 & SalePrice > 700000')
#Drop 692
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 691  692          60       RL  ...        WD         Normal    755000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='YearBuilt', y='SalePrice', data=train_df)

# %%
train_df.query('YearBuilt < 1900 & SalePrice > 400000')
# Drop 186
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 185  186          75       RM  ...        WD         Normal    475000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='YearRemodAdd', y='SalePrice', data=train_df)

# %%
train_df.query('YearRemodAdd < 1970 & SalePrice > 300000')
# Drop 314
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 313  314          20       RL  ...        WD         Normal    375000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='MasVnrArea', y='SalePrice', data=train_df)

# %%
train_df.query('MasVnrArea == 0 & SalePrice > 700000')
# Drop 1183
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1182  1183          60       RL  ...        WD        Abnorml    745000
#
# [1 rows x 81 columns]

# %%
train_df.query('MasVnrArea > 1500')
# Drop 298
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 297  298          60       FV  ...        WD         Normal    239000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtFinSF1', y='SalePrice', data=train_df)

# %%
train_df.query('BsmtFinSF1 > 5000')
# Drop 1299
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1298  1299          60       RL  ...       New        Partial    160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtFinSF2', y='SalePrice', data=train_df)

# %%
train_df.query('BsmtFinSF2 > 400 & SalePrice > 500000')
# Drop 441
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 440  441          20       RL  ...        WD         Normal    555000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtUnfSF', y='SalePrice', data=train_df)
plt.xlabel('BsmtUnfSF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
train_df.query('BsmtUnfSF < 500 & SalePrice > 700000')
# Drop 1183
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1182  1183          60       RL  ...        WD        Abnorml    745000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='TotalBsmtSF', y='SalePrice', data=train_df)
plt.xlabel('TotalBsmtSF')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('TotalBsmtSF > 6000')
# Drop 1299
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1298  1299          60       RL  ...       New        Partial    160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='1stFlrSF', y='SalePrice', data=train_df)
plt.xlabel('1stFlrSF')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='2ndFlrSF', y='SalePrice', data=train_df)
plt.xlabel('2ndFlrSF')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='LowQualFinSF', y='SalePrice', data=train_df)
plt.xlabel('LowQualFinSF')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('LowQualFinSF > 500 & SalePrice > 400000')
#Drop 186
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 185  186          75       RM  ...        WD         Normal    475000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='GrLivArea', y='SalePrice', data=train_df)
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('GrLivArea > 4400')
# Drop 524, 1299
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 523    524          60       RL  ...       New        Partial    184750
# 1182  1183          60       RL  ...        WD        Abnorml    745000
# 1298  1299          60       RL  ...       New        Partial    160000
#
# [3 rows x 81 columns]

# %%
plt.scatter(x='BsmtFullBath', y='SalePrice', data=train_df)
plt.xlabel('BsmtFullBath ')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('BsmtFullBath == 3')
#Drop 739
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 738  739          90       RL  ...        WD         Alloca    179000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtHalfBath', y='SalePrice', data=train_df)
plt.xlabel('BsmtHalfBath ')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('BsmtHalfBath == 2.00')
# Drop 598, 955
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 597  598         120       RL  ...       New        Partial    194201
# 954  955          90       RL  ...        WD        AdjLand    127500
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='FullBath', y='SalePrice', data=train_df)
plt.xlabel('FullBath ')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='HalfBath', y='SalePrice', data=train_df)
plt.xlabel('HalfBath')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='BedroomAbvGr', y='SalePrice', data=train_df)
plt.xlabel('BedroomAbvGr')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('BedroomAbvGr == 8')
#Drop 636
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 635  636         190       RH  ...        WD        Abnorml    200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='KitchenAbvGr', y='SalePrice', data=train_df)
plt.xlabel('KitchenAbvGr')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('KitchenAbvGr == 3')
# Drop 49, 810
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 48    49         190       RM  ...       New        Partial    113000
# 809  810          75       RM  ...        WD         Normal    106000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='TotRmsAbvGrd', y='SalePrice', data=train_df)
plt.xlabel('TotRmsAbvGrd')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('TotRmsAbvGrd == 14')
#Drop mybe 636
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 635  636         190       RH  ...        WD        Abnorml    200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='Fireplaces', y='SalePrice', data=train_df)
plt.xlabel('Fireplaces')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='GarageYrBlt', y='SalePrice', data=train_df)
plt.xlabel('GarageYrBlt')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='GarageCars', y='SalePrice', data=train_df)
plt.xlabel('GarageCars')
plt.ylabel('SalePrice')
plt.show()

# %%
scipy.stats.zscore(train_df['GarageCars']).unique()
# Out:
# array([ 0.31172464,  1.65030694, -1.02685765, -2.36543995,  2.98888924])

# %%
plt.scatter(x='GarageArea', y='SalePrice', data=train_df)
plt.xlabel('GarageArea')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('GarageArea > 1200')
#Drop 1062, 1191,1299
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 581    582          20       RL  ...       New        Partial    253293
# 825    826          20       RL  ...       New        Partial    385000
# 1061  1062          30  C (all)  ...     ConLD         Normal     81000
# 1190  1191         190       RL  ...        WD         Normal    168000
# 1298  1299          60       RL  ...       New        Partial    160000
#
# [5 rows x 81 columns]

# %%
plt.scatter(x='WoodDeckSF', y='SalePrice', data=train_df)
plt.xlabel('WoodDeckSF')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='OpenPorchSF', y='SalePrice', data=train_df)
plt.xlabel('OpenPorchSF')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('OpenPorchSF > 500')
# Drop 496
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 495    496          30  C (all)  ...        WD        Abnorml     34900
# 583    584          75       RM  ...        WD         Normal    325000
# 1328  1329          50       RM  ...        WD         Normal    256000
#
# [3 rows x 81 columns]

# %%
plt.scatter(x='EnclosedPorch', y='SalePrice', data=train_df)
plt.xlabel('EnclosedPorch')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('EnclosedPorch > 500')
# Drop 198
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 197  198          75       RL  ...        WD        Abnorml    235000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='3SsnPorch', y='SalePrice', data=train_df)
plt.xlabel('3SsnPorch')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='ScreenPorch', y='SalePrice', data=train_df)
plt.xlabel('ScreenPorch')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='PoolArea', y='SalePrice', data=train_df)
plt.xlabel('PoolArea')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='MiscVal', y='SalePrice', data=train_df)
plt.xlabel('MiscVal')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.query('MiscVal > 14000')
# Drop 347
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 346  347          20       RL  ...        WD         Normal    151500
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='MoSold', y='SalePrice', data=train_df)
plt.xlabel('MoSold')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x='YrSold', y='SalePrice', data=train_df)
plt.xlabel('YrSold')
plt.ylabel('SalePrice')
plt.show()

# %%
values = [935,1299,250,314,336,707,1397,524,379,1183,186,298,441,739,598,955,636,49,810,1062,119,198,347]

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
train_df = train_df[train_df.Id.isin(values) == False]
# isin() method returns if the given numbers are in the dataframe or not and returns True or False
# so we specify that return us just those values which are not in the values variale
# which means all the values except the given ones will e returned 
#In this way we will drop these values

# %%
train_df.shape
# Out:
# (1437, 81)

# %%
pd.DataFrame(train_df.isnull().sum().sort_values(ascending=False)).head(20)
# Out:
#                  0
# PoolQC        1433
# MiscFeature   1387
# Alley         1348
# Fence         1160
# MasVnrType     858
# FireplaceQu    683
# LotFrontage    254
# GarageYrBlt     77
# GarageCond      77
# GarageType      77
# GarageFinish    77
# GarageQual      77
# BsmtFinType2    38
# BsmtExposure    38
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# MasVnrArea       8
# Electrical       1
# Id               0

# %%
train_df['Alley'].fillna('No', inplace=True)
test_df['Alley'].fillna('No', inplace=True)
# Out:
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\672342038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Alley'].fillna('No', inplace=True)

# %%
train_df['Alley'].value_counts()
# Out:
# Alley
# No      1348
# Grvl      50
# Pave      39
# Name: count, dtype: int64

# %%
sns.catplot(data=train_df, x = 'Alley', y='SalePrice', kind='box')

# %%
train_df['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
train_df['Fence'].fillna('No', inplace=True)
test_df['Fence'].fillna('No', inplace=True)
# Out:
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\3730986352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Fence'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x = 'Fence', y = 'SalePrice', kind='box')

# %%
train_df['MasVnrType'].unique()
# Out:
# array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
train_df['MasVnrType'].fillna('No', inplace=True)
train_df['MasVnrType'].fillna('No', inplace=True)
# Out:
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\2052051024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MasVnrType'].fillna('No', inplace=True)
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\2052051024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MasVnrType'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x = 'MasVnrType', y = 'SalePrice', kind='box')

# %%
train_df['MasVnrArea'].fillna(0, inplace=True)
test_df['MasVnrArea'].fillna(0, inplace=True)
# Out:
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\3657060107.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MasVnrArea'].fillna(0, inplace=True)

# %%
train_df['FireplaceQu'].unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
train_df['FireplaceQu'].fillna('No', inplace=True)
train_df['FireplaceQu'].fillna('No', inplace=True)
# Out:
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\4077410323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'].fillna('No', inplace=True)
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\4077410323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x = 'FireplaceQu', y = 'SalePrice', kind='box')

# %%
train_df['LotFrontage'].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  52., 100.,  24.,  89.,  63.,  76.,  81.,
#         95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,  77.,
#         64.,  94.,  34.,  55.,  88.,  82.,  71., 120., 107.,  92., 134.,
#         62.,  86., 141.,  97.,  54.,  41.,  79.,  99.,  67.,  83.,  43.,
#        103., 174.,  93.,  30., 129., 140.,  35.,  37.,  90., 118.,  87.,
#        116., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,  38., 109.,
#        130.,  53., 137.,  45., 106., 104.,  42.,  39., 144., 114., 128.,
#        149., 168., 182., 138., 152., 124., 153.,  46.])

# %%
train_df['LotFrontage'].fillna(0, inplace=True)
test_df['LotFrontage'].fillna(0,inplace=True)
# Out:
# C:\Users\BASIT\AppData\Local\Temp\ipykernel_7092\356423265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['LotFrontage'].fillna(0, inplace=True)

# %%
train_df['GarageYrBlt'].unique()
# Out:
# array([2003., 1976., 2001., 1998., 2000., 1993., 2004., 1973., 1931.,
#        1939., 1965., 2005., 1962., 2006., 1960., 1991., 1970., 1967.,
#        1958., 1930., 2002., 1968., 2007., 2008., 1957., 1920., 1966.,
#        1959., 1995., 1954., 1953.,   nan, 1983., 1977., 1997., 1985.,
#        1963., 1981., 1964., 1999., 1935., 1990., 1945., 1987., 1989.,
#        1915., 1956., 1948., 1974., 2009., 1950., 1961., 1921., 1900.,
#        1979., 1951., 1969., 1936., 1975., 1971., 1923., 1984., 1926.,
#        1955., 1986., 1988., 1916., 1932., 1972., 1980., 1924., 1996.,
#        1940., 1949., 1994., 1910., 1978., 1982., 1992., 1925., 1941.,
#        1927., 1918., 1947., 1937., 1942., 1938., 1952., 1928., 1922.,
#        1934., 1906., 1914., 2010., 1946., 1908., 1929., 1933.])

# %%
"""
GarageYrBlt	77
GarageCond	77
GarageType	77
GarageFinish	77
GarageQual	77
BsmtFinType2	38
BsmtExposure	38
BsmtQual	37
BsmtCond	37
BsmtFinType1	37
Electrical	1
"""
